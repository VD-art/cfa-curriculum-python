# %% [markdown]
# <a href="https://colab.research.google.com/github/VD-art/cfa-curriculum-python/blob/main/notebooks/quant/02_required_return_components.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📍 Lesson 1 – Topic 2: Components of Required Return
#
# We break required return into:
# - Real risk-free rate
# - Inflation premium
# - Default risk premium
# - Liquidity premium
# - Maturity premium
#
# Required return = sum of these components.

# %%
# !git clone https://github.com/VD-art/cfa-curriculum-python.git

import sys
sys.path.append('/content/cfa-curriculum-python')
# Out:
# Cloning into 'cfa-curriculum-python'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 77 (delta 22), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (77/77), 23.93 KiB | 7.98 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
from scripts.quant.required_return_components import calculate_required_return_components

# %%
inputs = {
    'real_risk_free_rate': 0.02,
    'inflation_premium': 0.015,
    'default_risk_premium': 0.01,
    'liquidity_premium': 0.005,
    'maturity_premium': 0.004
}

result = calculate_required_return_components(**inputs)

print("Components:")
for k, v in result.items():
    print(f"{k}: {v:.2%}")
# Out:
# Components:
# real_risk_free_rate: 2.00%
# inflation_premium: 1.50%
# default_risk_premium: 1.00%
# liquidity_premium: 0.50%
# maturity_premium: 0.40%
# required_return: 5.40%

# %%
import matplotlib.pyplot as plt

components = list(result.keys())[:-1]
values = [result[c] for c in components]

plt.barh(components, values)
plt.xlabel('Contribution')
plt.title('Required Return Components')
plt.show()
